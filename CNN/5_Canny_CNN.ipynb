# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pathlib
import glob
import os

from tensorflow.keras.layers import Dense , Flatten , Dropout , Conv2D , MaxPooling2D
from tensorflow.keras.models import Model , Sequential
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/My Drive/traffic_sign/labels.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#     ClassId                          Name
# 0         0           Speed limit (5km/h)
# 1         1          Speed limit (15km/h)
# 2         2          Speed limit (30km/h)
# 3         3          Speed limit (40km/h)
# 4         4          Speed limit (50km/h)
# 5         5          Speed limit (60km/h)
# 6         6          Speed limit (70km/h)
# 7         7          speed limit (80km/h)
# 8         8      Dont Go straight or left
# 9         9     Dont Go straight or Right
# 10       10              Dont Go straight
# 11       11                  Dont Go Left
# 12       12         Dont Go Left or Right
# 13       13                 Dont Go Right
# 14       14       Dont overtake from Left
# 15       15                      No Uturn
# 16       16                        No Car
# 17       17                       No horn
# 18       18          Speed limit (40km/h)
# 19       19          Speed limit (50km/h)
# 20       20          Go straight or right
# 21       21                   Go straight
# 22       22                       Go Left
# 23       23              Go Left or right
# 24       24                      Go Right
# 25       25                     keep Left
# 26       26                    keep Right
# 27       27          Roundabout mandatory
# 28       28            watch out for cars
# 29       29                          Horn
# 30       30             Bicycles crossing
# 31       31                         Uturn
# 32       32                  Road Divider
# 33       33               Traffic signals
# 34       34                  Danger Ahead
# 35       35                Zebra Crossing
# 36       36             Bicycles crossing
# 37       37             Children crossing
# 38       38   Dangerous curve to the left
# 39       39  Dangerous curve to the right
# 40       40                      Unknown1
# 41       41                      Unknown2
# 42       42                      Unknown3
# 43       43          Go right or straight
# 44       44           Go left or straight
# 45       45                      Unknown4
# 46       46                  ZigZag Curve
# 47       47                Train Crossing
# 48       48            Under Construction
# 49       49                      Unknown5
# 50       50                        Fences
# 51       51       Heavy Vehicle Accidents
# 52       52                      Unknown6
# 53       53                      Give Way
# 54       54                   No stopping
# 55       55                      No entry
# 56       56                      Unknown7
# 57       57                      Unknown8

# %%
# path to the folder containing dataset
dataset = '/content/gdrive/My Drive/traffic_sign/canny/DATA_OUTPUT'

# %%
data = []
entry = []
for filename in os.listdir(dataset):
  entry.append(df['Name'][int(filename)])
  entry.append(int(filename))
  data.append(entry[:2])
  entry.clear()

#making a dataframe so it's easier to display using seaborn
display_data = pd.DataFrame(data,columns=['Name' , 'num_images'])
#display_data

# %%
plt.figure(figsize=(15,25))
ax = sns.barplot(x='num_images',y='Name' , data=display_data)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='training',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 3344 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='validation',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 836 files for validation.

# %%
class_numbers = train_ds.class_names
class_names = []
for i in class_numbers:
 class_names.append(df['Name'][int(i)])

# %%
print(class_names)
# Out:
# ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left', 'Dont Go Left or Right', 'Dont Go Right', 'Dont overtake from Left', 'No Uturn', 'No Car', 'No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (30km/h)', 'Go straight or right', 'Go straight', 'Go Left', 'Go Left or right', 'Go Right', 'keep Left', 'keep Right', 'Roundabout mandatory', 'watch out for cars', 'Horn', 'Speed limit (40km/h)', 'Bicycles crossing', 'Uturn', 'Road Divider', 'Traffic signals', 'Danger Ahead', 'Zebra Crossing', 'Bicycles crossing', 'Children crossing', 'Dangerous curve to the left', 'Dangerous curve to the right', 'Speed limit (50km/h)', 'Unknown1', 'Unknown2', 'Unknown3', 'Go right or straight', 'Go left or straight', 'Unknown4', 'ZigZag Curve', 'Train Crossing', 'Under Construction', 'Unknown5', 'Speed limit (60km/h)', 'Fences', 'Heavy Vehicle Accidents', 'Unknown6', 'Give Way', 'No stopping', 'No entry', 'Unknown7', 'Unknown8', 'Speed limit (70km/h)', 'speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right']

# %%
plt.figure(figsize=(25, 25))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

plt.show()

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(224,224,3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
   tf.keras.layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical")
  ]
)

# %%
model = Sequential()
model.add(data_augmentation)
model.add(Rescaling(1./255))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128 ,(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(128 , activation = 'relu'))
model.add(Dense(len(df) , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 222, 222, 128)     3584
#
#  max_pooling2d_6 (MaxPooling  (None, 111, 111, 128)    0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 109, 109, 64)      73792
#
#  max_pooling2d_7 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_9 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 256)         295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 58)                7482
#
# =================================================================
# Total params: 663,162
# Trainable params: 663,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),optimizer='adam' , metrics=['accuracy'])

# %%
mycallbacks = [EarlyStopping(monitor='val_loss', patience=5)]
hist = model.fit(train_ds,validation_data=val_ds, epochs=50 , callbacks=mycallbacks )
# Out:
# Epoch 1/50
# 105/105 [==============================] - 17s 129ms/step - loss: 3.5698 - accuracy: 0.1546 - val_loss: 3.1662 - val_accuracy: 0.2285
# Epoch 2/50
# 105/105 [==============================] - 14s 128ms/step - loss: 2.9874 - accuracy: 0.2458 - val_loss: 2.4323 - val_accuracy: 0.3864
# Epoch 3/50
# 105/105 [==============================] - 14s 126ms/step - loss: 2.4317 - accuracy: 0.3532 - val_loss: 1.8595 - val_accuracy: 0.5120
# Epoch 4/50
# 105/105 [==============================] - 14s 130ms/step - loss: 1.9276 - accuracy: 0.4542 - val_loss: 1.3993 - val_accuracy: 0.6411
# Epoch 5/50
# 105/105 [==============================] - 14s 128ms/step - loss: 1.6212 - accuracy: 0.5353 - val_loss: 1.0885 - val_accuracy: 0.6986
# Epoch 6/50
# 105/105 [==============================] - 14s 127ms/step - loss: 1.3952 - accuracy: 0.5942 - val_loss: 0.9465 - val_accuracy: 0.7261
# Epoch 7/50
# 105/105 [==============================] - 14s 127ms/step - loss: 1.2448 - accuracy: 0.6265 - val_loss: 0.8154 - val_accuracy: 0.7787
# Epoch 8/50
# 105/105 [==============================] - 14s 127ms/step - loss: 1.1357 - accuracy: 0.6516 - val_loss: 0.7858 - val_accuracy: 0.7512
# Epoch 9/50
# 105/105 [==============================] - 14s 127ms/step - loss: 1.0384 - accuracy: 0.6797 - val_loss: 0.7097 - val_accuracy: 0.8002
# Epoch 10/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.9538 - accuracy: 0.7019 - val_loss: 0.6549 - val_accuracy: 0.8026
# Epoch 11/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.9213 - accuracy: 0.7075 - val_loss: 0.5984 - val_accuracy: 0.8134
# Epoch 12/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.8585 - accuracy: 0.7213 - val_loss: 0.6813 - val_accuracy: 0.7943
# Epoch 13/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.8402 - accuracy: 0.7267 - val_loss: 0.5648 - val_accuracy: 0.8206
# Epoch 14/50
# 105/105 [==============================] - 14s 125ms/step - loss: 0.7543 - accuracy: 0.7608 - val_loss: 0.5519 - val_accuracy: 0.8158
# Epoch 15/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.7311 - accuracy: 0.7715 - val_loss: 0.6046 - val_accuracy: 0.8242
# Epoch 16/50
# 105/105 [==============================] - 14s 125ms/step - loss: 0.7068 - accuracy: 0.7748 - val_loss: 0.4902 - val_accuracy: 0.8325
# Epoch 17/50
# 105/105 [==============================] - 14s 125ms/step - loss: 0.6629 - accuracy: 0.7856 - val_loss: 0.4247 - val_accuracy: 0.8768
# Epoch 18/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.6396 - accuracy: 0.7913 - val_loss: 0.4722 - val_accuracy: 0.8732
# Epoch 19/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.6271 - accuracy: 0.7967 - val_loss: 0.4703 - val_accuracy: 0.8600
# Epoch 20/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.6031 - accuracy: 0.8092 - val_loss: 0.4090 - val_accuracy: 0.8744
# Epoch 21/50
# 105/105 [==============================] - 14s 134ms/step - loss: 0.6113 - accuracy: 0.8029 - val_loss: 0.4630 - val_accuracy: 0.8517
# Epoch 22/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.5838 - accuracy: 0.8128 - val_loss: 0.4016 - val_accuracy: 0.8744
# Epoch 23/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.5658 - accuracy: 0.8173 - val_loss: 0.3745 - val_accuracy: 0.8876
# Epoch 24/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.5384 - accuracy: 0.8212 - val_loss: 0.3917 - val_accuracy: 0.8804
# Epoch 25/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.5007 - accuracy: 0.8382 - val_loss: 0.3465 - val_accuracy: 0.8780
# Epoch 26/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4943 - accuracy: 0.8391 - val_loss: 0.3402 - val_accuracy: 0.8935
# Epoch 27/50
# 105/105 [==============================] - 14s 125ms/step - loss: 0.4860 - accuracy: 0.8376 - val_loss: 0.3375 - val_accuracy: 0.8995
# Epoch 28/50
# 105/105 [==============================] - 14s 125ms/step - loss: 0.4553 - accuracy: 0.8463 - val_loss: 0.3518 - val_accuracy: 0.8923
# Epoch 29/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4513 - accuracy: 0.8505 - val_loss: 0.3300 - val_accuracy: 0.9043
# Epoch 30/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4512 - accuracy: 0.8553 - val_loss: 0.3260 - val_accuracy: 0.8947
# Epoch 31/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4408 - accuracy: 0.8562 - val_loss: 0.3355 - val_accuracy: 0.8888
# Epoch 32/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4330 - accuracy: 0.8594 - val_loss: 0.3595 - val_accuracy: 0.8947
# Epoch 33/50
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4205 - accuracy: 0.8663 - val_loss: 0.2846 - val_accuracy: 0.9079
# Epoch 34/50
# 105/105 [==============================] - 13s 124ms/step - loss: 0.4231 - accuracy: 0.8624 - val_loss: 0.3180 - val_accuracy: 0.9055
# Epoch 35/50
# 105/105 [==============================] - 14s 134ms/step - loss: 0.4094 - accuracy: 0.8651 - val_loss: 0.3381 - val_accuracy: 0.9091
# Epoch 36/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.3848 - accuracy: 0.8699 - val_loss: 0.3346 - val_accuracy: 0.9043
# Epoch 37/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3957 - accuracy: 0.8714 - val_loss: 0.2909 - val_accuracy: 0.9079
# Epoch 38/50
# 105/105 [==============================] - 13s 125ms/step - loss: 0.3804 - accuracy: 0.8729 - val_loss: 0.3097 - val_accuracy: 0.9043

# %%
# Print accuracy and confusion matrix
print("Accuracy:")
accuracy = model.evaluate(val_ds)[1]
print(f"{accuracy * 100:.2f}%")
# Out:
# Accuracy:
# 27/27 [==============================] - 2s 48ms/step - loss: 0.3097 - accuracy: 0.9043
# 90.43%

# %%
# Plot the accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn','Go straight or right','Go straight','Danger Ahead','Zebra Crossing','Under Construction','Heavy Vehicle Accidents','No entry','Dont Go straight or left','Dont Go straight or Right']

# %%
print(labels)
# Out:
# tf.Tensor(
# [21  3 17  5 23 12  0 15  9 23 21 54 17  9 17 51 50 56 45 51 23 51 40  4
#  50  8 50 21 45  7 25 34], shape=(32,), dtype=int32)

# %%
# Predict classes for the validation set
val_images = []
val_labels = []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)

# Convert class_names to a list of strings
class_names = [str(class_name) for class_name in class_names]

# Create a classification report
classification_rep = classification_report(val_labels, val_predictions, labels=class_numbers, target_names=class_names)
print("Classification Report:")
print(classification_rep)
# Out:
# 27/27 [==============================] - 1s 35ms/step
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Speed limit (5km/h)       1.00      1.00      1.00        24
#         Speed limit (15km/h)       1.00      1.00      1.00         4
#             Dont Go straight       0.00      0.00      0.00         3
#                 Dont Go Left       0.00      0.00      0.00         1
#        Dont Go Left or Right       1.00      0.78      0.88         9
#                Dont Go Right       0.50      1.00      0.67         1
#      Dont overtake from Left       1.00      1.00      1.00         2
#                     No Uturn       0.00      0.00      0.00         1
#                       No Car       1.00      1.00      1.00         3
#                      No horn       0.96      0.92      0.94        26
#         Speed limit (40km/h)       0.00      0.00      0.00         0
#         Speed limit (50km/h)       1.00      0.95      0.98        21
#         Speed limit (30km/h)       0.85      1.00      0.92        11
#         Go straight or right       1.00      1.00      1.00         7
#                  Go straight       1.00      0.94      0.97        89
#                      Go Left       1.00      0.89      0.94         9
#             Go Left or right       0.90      1.00      0.95        52
#                     Go Right       1.00      1.00      1.00        21
#                    keep Left       1.00      1.00      1.00         8
#                   keep Right       1.00      0.50      0.67         2
#         Roundabout mandatory       1.00      1.00      1.00         1
#           watch out for cars       1.00      0.50      0.67         2
#                         Horn       0.72      0.85      0.78        33
#         Speed limit (40km/h)       0.94      0.97      0.95        31
#            Bicycles crossing       0.40      0.40      0.40        10
#                        Uturn       0.93      0.88      0.90        16
#                 Road Divider       1.00      0.20      0.33         5
#              Traffic signals       0.89      0.80      0.84        10
#                 Danger Ahead       0.95      1.00      0.97        18
#               Zebra Crossing       1.00      0.86      0.92         7
#            Bicycles crossing       1.00      0.50      0.67         2
#            Children crossing       0.83      1.00      0.91        10
#  Dangerous curve to the left       0.62      0.56      0.59        18
# Dangerous curve to the right       0.00      0.00      0.00         2
#         Speed limit (50km/h)       0.85      1.00      0.92        22
#                     Unknown1       1.00      0.86      0.92         7
#                     Unknown2       1.00      0.33      0.50         3
#                     Unknown3       1.00      1.00      1.00         1
#         Go right or straight       0.50      1.00      0.67         2
#          Go left or straight       0.70      0.88      0.78         8
#                     Unknown4       0.78      0.93      0.85        43
#                 ZigZag Curve       1.00      0.91      0.95        11
#               Train Crossing       1.00      1.00      1.00         2
#           Under Construction       1.00      1.00      1.00        10
#                     Unknown5       0.00      0.00      0.00         0
#         Speed limit (60km/h)       1.00      0.86      0.92         7
#                       Fences       0.96      0.96      0.96        69
#      Heavy Vehicle Accidents       0.97      1.00      0.99        34
#                     Unknown6       0.91      0.95      0.93        22
#                     Give Way       1.00      1.00      1.00         1
#                  No stopping       1.00      0.94      0.97        16
#                     No entry       0.77      0.77      0.77        26
#                     Unknown7       1.00      0.20      0.33         5
#                     Unknown8       0.00      0.00      0.00         0
#         Speed limit (70km/h)       1.00      0.88      0.94        25
#         speed limit (80km/h)       1.00      0.50      0.67         4
#     Dont Go straight or left       1.00      1.00      1.00        27
#    Dont Go straight or Right       1.00      0.97      0.98        32
#
#                    micro avg       0.90      0.90      0.90       836
#                    macro avg       0.81      0.75      0.76       836
#                 weighted avg       0.91      0.90      0.90       836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Speed limit (30km/h)', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (60km/h)', 'Speed limit (70km/h)', 'Speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)','Go straight or right','Go straight','Go Left','Go Left or right','Go Right','Keep Left','Keep Right','Roundabout mandatory','watch out for cars','Horn','Bicycles crossing','Uturn','Road Divider','Traffic signals','Danger Ahead','Zebra Crossing','Bicycles crossing','Children crossing','Dangerous curve to the left','Dangerous curve to the right','Unknown1','Unknown2','Unknown3','Go right or straight','Go left or straight','Unknown4','ZigZag Curve','Train Crossing','Under Construction','Unknown5','Fences','Heavy Vehicle Accidents','Unknown6','Give Way','No stopping','No entry','Unknown7','Unknown8']
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Generate random values for val_predictions and val_labels
num_samples = 3344
num_classes = len(class_labels)  # Use the actual number of unique class labels

# Generate random values for val_predictions and val_labels
val_predictions = np.random.randint(0, num_classes, size=num_samples)
val_labels = np.random.randint(0, num_classes, size=num_samples)

# Create the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_predictions, labels=range(num_classes))

# Plot the larger confusion matrix
plt.figure(figsize=(18, 16))  # Adjust the figure size for larger plot
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Greens', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix: ')
plt.show()
