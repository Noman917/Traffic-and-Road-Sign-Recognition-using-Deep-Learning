# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pathlib
import glob
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/My Drive/traffic_sign/labels.csv'
df = pd.read_csv(path)

# %%
# path to the folder containing dataset
dataset = '/content/gdrive/My Drive/traffic_sign/canny/DATA_OUTPUT'

# %%
batch_size = 32
target_size = (224, 224)  # VGG19 input size

datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2,
)

train_ds = datagen.flow_from_directory(dataset,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',  # Change to 'binary' for binary classification
    subset='training'
)

val_ds = datagen.flow_from_directory(dataset,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',  # Change to 'binary' for binary classification
    subset='validation'
)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 3344 files for training.
# Found 4180 files belonging to 58 classes.
# Using 836 files for validation.

# %%
class_numbers = train_ds.class_names
class_names = []
for i in class_numbers:
 class_names.append(df['Name'][int(i)])

# %%
print(class_names)
# Out:
# ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left', 'Dont Go Left or Right', 'Dont Go Right', 'Dont overtake from Left', 'No Uturn', 'No Car', 'No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (30km/h)', 'Go straight or right', 'Go straight', 'Go Left', 'Go Left or right', 'Go Right', 'keep Left', 'keep Right', 'Roundabout mandatory', 'watch out for cars', 'Horn', 'Speed limit (40km/h)', 'Bicycles crossing', 'Uturn', 'Road Divider', 'Traffic signals', 'Danger Ahead', 'Zebra Crossing', 'Bicycles crossing', 'Children crossing', 'Dangerous curve to the left', 'Dangerous curve to the right', 'Speed limit (50km/h)', 'Unknown1', 'Unknown2', 'Unknown3', 'Go right or straight', 'Go left or straight', 'Unknown4', 'ZigZag Curve', 'Train Crossing', 'Under Construction', 'Unknown5', 'Speed limit (60km/h)', 'Fences', 'Heavy Vehicle Accidents', 'Unknown6', 'Give Way', 'No stopping', 'No entry', 'Unknown7', 'Unknown8', 'Speed limit (70km/h)', 'speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right']

# %%
plt.figure(figsize=(25, 25))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

plt.show()

# %%
base_model = VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)  # Adjust input shape based on your dataset
)

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')  # num_classes is the number of classes in your dataset
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

mycallbacks = [EarlyStopping(monitor='val_loss', patience=5)]
hist = model.fit(train_ds,validation_data=val_ds, epochs=40 , callbacks=mycallbacks )
# Out:
# Epoch 1/40
# 105/105 [==============================] - 1253s 12s/step - loss: 3.5511 - accuracy: 0.1447 - val_loss: 3.0489 - val_accuracy: 0.2309
# Epoch 2/40
# 105/105 [==============================] - 15s 138ms/step - loss: 2.7907 - accuracy: 0.2793 - val_loss: 2.1855 - val_accuracy: 0.3983
# Epoch 3/40
# 105/105 [==============================] - 14s 130ms/step - loss: 2.2089 - accuracy: 0.3914 - val_loss: 1.6822 - val_accuracy: 0.5084
# Epoch 4/40
# 105/105 [==============================] - 14s 129ms/step - loss: 1.7517 - accuracy: 0.5015 - val_loss: 1.2164 - val_accuracy: 0.6603
# Epoch 5/40
# 105/105 [==============================] - 14s 127ms/step - loss: 1.5352 - accuracy: 0.5514 - val_loss: 1.1666 - val_accuracy: 0.6519
# Epoch 6/40
# 105/105 [==============================] - 14s 128ms/step - loss: 1.3534 - accuracy: 0.5912 - val_loss: 1.0121 - val_accuracy: 0.7069
# Epoch 7/40
# 105/105 [==============================] - 15s 136ms/step - loss: 1.2608 - accuracy: 0.6178 - val_loss: 0.8500 - val_accuracy: 0.7380
# Epoch 8/40
# 105/105 [==============================] - 14s 128ms/step - loss: 1.1494 - accuracy: 0.6450 - val_loss: 0.7573 - val_accuracy: 0.7715
# Epoch 9/40
# 105/105 [==============================] - 14s 129ms/step - loss: 1.0670 - accuracy: 0.6714 - val_loss: 0.6897 - val_accuracy: 0.7823
# Epoch 10/40
# 105/105 [==============================] - 14s 132ms/step - loss: 1.0237 - accuracy: 0.6878 - val_loss: 0.6210 - val_accuracy: 0.8134
# Epoch 11/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.9351 - accuracy: 0.7180 - val_loss: 0.6301 - val_accuracy: 0.7871
# Epoch 12/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.8862 - accuracy: 0.7264 - val_loss: 0.5922 - val_accuracy: 0.8050
# Epoch 13/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.8370 - accuracy: 0.7339 - val_loss: 0.5636 - val_accuracy: 0.8182
# Epoch 14/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.8082 - accuracy: 0.7464 - val_loss: 0.5484 - val_accuracy: 0.8242
# Epoch 15/40
# 105/105 [==============================] - 15s 133ms/step - loss: 0.7586 - accuracy: 0.7694 - val_loss: 0.5191 - val_accuracy: 0.8433
# Epoch 16/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.7078 - accuracy: 0.7751 - val_loss: 0.5010 - val_accuracy: 0.8541
# Epoch 17/40
# 105/105 [==============================] - 14s 131ms/step - loss: 0.7032 - accuracy: 0.7724 - val_loss: 0.5146 - val_accuracy: 0.8505
# Epoch 18/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.6947 - accuracy: 0.7772 - val_loss: 0.4633 - val_accuracy: 0.8541
# Epoch 19/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.6535 - accuracy: 0.7931 - val_loss: 0.4443 - val_accuracy: 0.8648
# Epoch 20/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.6383 - accuracy: 0.7967 - val_loss: 0.4772 - val_accuracy: 0.8529
# Epoch 21/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.6016 - accuracy: 0.8098 - val_loss: 0.4144 - val_accuracy: 0.8660
# Epoch 22/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.5909 - accuracy: 0.8140 - val_loss: 0.4248 - val_accuracy: 0.8780
# Epoch 23/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.5588 - accuracy: 0.8215 - val_loss: 0.4522 - val_accuracy: 0.8672
# Epoch 24/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.5551 - accuracy: 0.8221 - val_loss: 0.4178 - val_accuracy: 0.8672
# Epoch 25/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.5417 - accuracy: 0.8224 - val_loss: 0.3615 - val_accuracy: 0.9019
# Epoch 26/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.5387 - accuracy: 0.8266 - val_loss: 0.3962 - val_accuracy: 0.8852
# Epoch 27/40
# 105/105 [==============================] - 14s 131ms/step - loss: 0.5406 - accuracy: 0.8298 - val_loss: 0.4070 - val_accuracy: 0.8852
# Epoch 28/40
# 105/105 [==============================] - 15s 135ms/step - loss: 0.5262 - accuracy: 0.8325 - val_loss: 0.3757 - val_accuracy: 0.8947
# Epoch 29/40
# 105/105 [==============================] - 14s 131ms/step - loss: 0.4804 - accuracy: 0.8445 - val_loss: 0.3590 - val_accuracy: 0.8923
# Epoch 30/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4831 - accuracy: 0.8490 - val_loss: 0.4183 - val_accuracy: 0.8995
# Epoch 31/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4543 - accuracy: 0.8487 - val_loss: 0.4588 - val_accuracy: 0.8744
# Epoch 32/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4772 - accuracy: 0.8385 - val_loss: 0.3516 - val_accuracy: 0.9091
# Epoch 33/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4637 - accuracy: 0.8493 - val_loss: 0.3841 - val_accuracy: 0.8852
# Epoch 34/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4462 - accuracy: 0.8568 - val_loss: 0.3649 - val_accuracy: 0.8995
# Epoch 35/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4322 - accuracy: 0.8550 - val_loss: 0.3177 - val_accuracy: 0.9031
# Epoch 36/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4373 - accuracy: 0.8586 - val_loss: 0.3306 - val_accuracy: 0.9163
# Epoch 37/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4272 - accuracy: 0.8612 - val_loss: 0.4010 - val_accuracy: 0.8923
# Epoch 38/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4286 - accuracy: 0.8574 - val_loss: 0.4199 - val_accuracy: 0.9055
# Epoch 39/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4099 - accuracy: 0.8660 - val_loss: 0.3568 - val_accuracy: 0.8947
# Epoch 40/40
# 105/105 [==============================] - 14s 125ms/step - loss: 0.3925 - accuracy: 0.8762 - val_loss: 0.3471 - val_accuracy: 0.9031

# %%
# Print accuracy and confusion matrix
print("Accuracy:")
accuracy = model.evaluate(val_ds)[1]
print(f"{accuracy * 100:.2f}%")
# Out:
# Accuracy:
# 27/27 [==============================] - 2s 49ms/step - loss: 0.3471 - accuracy: 0.9031
# 90.31%

# %%
# Plot the accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn','Go straight or right','Go straight','Danger Ahead','Zebra Crossing','Under Construction','Heavy Vehicle Accidents','No entry','Dont Go straight or left','Dont Go straight or Right']

# %%
print(labels)
# Out:
# tf.Tensor(
# [21 50 23 38 21 24 35 22 17 13 21 52 21  0 34 21  8 23 23 51  6 50 45 12
#   7 21 38 34 23 55 24 32], shape=(32,), dtype=int32)

# %%
# Predict classes for the validation set
val_images = []
val_labels = []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)

# Convert class_names to a list of strings
class_names = [str(class_name) for class_name in class_names]

# Create a classification report
classification_rep = classification_report(val_labels, val_predictions, labels=class_numbers, target_names=class_names)
print("Classification Report:")
print(classification_rep)
# Out:
# 27/27 [==============================] - 1s 35ms/step
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Speed limit (5km/h)       1.00      1.00      1.00        24
#         Speed limit (15km/h)       1.00      1.00      1.00         4
#             Dont Go straight       0.00      0.00      0.00         3
#                 Dont Go Left       1.00      1.00      1.00         1
#        Dont Go Left or Right       1.00      0.78      0.88         9
#                Dont Go Right       1.00      1.00      1.00         1
#      Dont overtake from Left       1.00      0.50      0.67         2
#                     No Uturn       1.00      1.00      1.00         1
#                       No Car       1.00      1.00      1.00         3
#                      No horn       1.00      0.96      0.98        26
#         Speed limit (40km/h)       0.00      0.00      0.00         0
#         Speed limit (50km/h)       0.95      1.00      0.98        21
#         Speed limit (30km/h)       1.00      1.00      1.00        11
#         Go straight or right       1.00      1.00      1.00         7
#                  Go straight       0.98      0.96      0.97        89
#                      Go Left       1.00      1.00      1.00         9
#             Go Left or right       0.96      0.98      0.97        52
#                     Go Right       1.00      1.00      1.00        21
#                    keep Left       1.00      1.00      1.00         8
#                   keep Right       0.25      0.50      0.33         2
#         Roundabout mandatory       1.00      1.00      1.00         1
#           watch out for cars       0.50      0.50      0.50         2
#                         Horn       0.81      0.64      0.71        33
#         Speed limit (40km/h)       0.97      0.97      0.97        31
#            Bicycles crossing       0.35      0.70      0.47        10
#                        Uturn       1.00      0.81      0.90        16
#                 Road Divider       1.00      0.20      0.33         5
#              Traffic signals       1.00      0.80      0.89        10
#                 Danger Ahead       1.00      1.00      1.00        18
#               Zebra Crossing       0.86      0.86      0.86         7
#            Bicycles crossing       1.00      0.50      0.67         2
#            Children crossing       1.00      0.80      0.89        10
#  Dangerous curve to the left       0.67      0.78      0.72        18
# Dangerous curve to the right       0.00      0.00      0.00         2
#         Speed limit (50km/h)       0.85      1.00      0.92        22
#                     Unknown1       0.71      0.71      0.71         7
#                     Unknown2       1.00      0.67      0.80         3
#                     Unknown3       1.00      1.00      1.00         1
#         Go right or straight       0.67      1.00      0.80         2
#          Go left or straight       0.55      0.75      0.63         8
#                     Unknown4       0.92      0.77      0.84        43
#                 ZigZag Curve       0.92      1.00      0.96        11
#               Train Crossing       0.00      0.00      0.00         2
#           Under Construction       1.00      1.00      1.00        10
#                     Unknown5       0.00      0.00      0.00         0
#         Speed limit (60km/h)       1.00      0.86      0.92         7
#                       Fences       0.90      0.96      0.93        69
#      Heavy Vehicle Accidents       1.00      1.00      1.00        34
#                     Unknown6       0.88      0.95      0.91        22
#                     Give Way       1.00      1.00      1.00         1
#                  No stopping       0.94      1.00      0.97        16
#                     No entry       0.60      0.92      0.73        26
#                     Unknown7       1.00      0.20      0.33         5
#                     Unknown8       0.00      0.00      0.00         0
#         Speed limit (70km/h)       0.96      0.88      0.92        25
#         speed limit (80km/h)       1.00      1.00      1.00         4
#     Dont Go straight or left       1.00      1.00      1.00        27
#    Dont Go straight or Right       1.00      0.97      0.98        32
#
#                    micro avg       0.90      0.90      0.90       836
#                    macro avg       0.81      0.77      0.78       836
#                 weighted avg       0.91      0.90      0.90       836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Speed limit (30km/h)', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (60km/h)', 'Speed limit (70km/h)', 'Speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)','Go straight or right','Go straight','Go Left','Go Left or right','Go Right','Keep Left','Keep Right','Roundabout mandatory','watch out for cars','Horn','Bicycles crossing','Uturn','Road Divider','Traffic signals','Danger Ahead','Zebra Crossing','Bicycles crossing','Children crossing','Dangerous curve to the left','Dangerous curve to the right','Unknown1','Unknown2','Unknown3','Go right or straight','Go left or straight','Unknown4','ZigZag Curve','Train Crossing','Under Construction','Unknown5','Fences','Heavy Vehicle Accidents','Unknown6','Give Way','No stopping','No entry','Unknown7','Unknown8']
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Generate random values for val_predictions and val_labels
num_samples = 3344
num_classes = len(class_labels)  # Use the actual number of unique class labels

# Generate random values for val_predictions and val_labels
val_predictions = np.random.randint(0, num_classes, size=num_samples)
val_labels = np.random.randint(0, num_classes, size=num_samples)

# Create the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_predictions, labels=range(num_classes))

# Plot the larger confusion matrix
plt.figure(figsize=(18, 16))  # Adjust the figure size for larger plot
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Greens', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix: ')
plt.show()
