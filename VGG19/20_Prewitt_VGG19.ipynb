# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pathlib
import glob
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/My Drive/traffic_sign/labels.csv'
df = pd.read_csv(path)

# %%
# path to the folder containing dataset
dataset = '/content/gdrive/My Drive/traffic_sign/prewitt/DATA_OUTPUT'

# %%
batch_size = 32
target_size = (224, 224)  # VGG19 input size

datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2,
)

train_ds = datagen.flow_from_directory(dataset,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',  # Change to 'binary' for binary classification
    subset='training'
)

val_ds = datagen.flow_from_directory(dataset,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',  # Change to 'binary' for binary classification
    subset='validation'
)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 3344 files for training.
# Found 4180 files belonging to 58 classes.
# Using 836 files for validation.

# %%
class_numbers = train_ds.class_names
class_names = []
for i in class_numbers:
 class_names.append(df['Name'][int(i)])

# %%
print(class_names)
# Out:
# ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left', 'Dont Go Left or Right', 'Dont Go Right', 'Dont overtake from Left', 'No Uturn', 'No Car', 'No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (30km/h)', 'Go straight or right', 'Go straight', 'Go Left', 'Go Left or right', 'Go Right', 'keep Left', 'keep Right', 'Roundabout mandatory', 'watch out for cars', 'Horn', 'Speed limit (40km/h)', 'Bicycles crossing', 'Uturn', 'Road Divider', 'Traffic signals', 'Danger Ahead', 'Zebra Crossing', 'Bicycles crossing', 'Children crossing', 'Dangerous curve to the left', 'Dangerous curve to the right', 'Speed limit (50km/h)', 'Unknown1', 'Unknown2', 'Unknown3', 'Go right or straight', 'Go left or straight', 'Unknown4', 'ZigZag Curve', 'Train Crossing', 'Under Construction', 'Unknown5', 'Speed limit (60km/h)', 'Fences', 'Heavy Vehicle Accidents', 'Unknown6', 'Give Way', 'No stopping', 'No entry', 'Unknown7', 'Unknown8', 'Speed limit (70km/h)', 'speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right']

# %%
plt.figure(figsize=(25, 25))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

plt.show()

# %%
base_model = VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)  # Adjust input shape based on your dataset
)

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')  # num_classes is the number of classes in your dataset
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

mycallbacks = [EarlyStopping(monitor='val_loss', patience=5)]
hist = model.fit(train_ds,validation_data=val_ds, epochs=40 , callbacks=mycallbacks )
# Out:
# Epoch 1/40
# 105/105 [==============================] - 516s 5s/step - loss: 3.6918 - accuracy: 0.0945 - val_loss: 3.4907 - val_accuracy: 0.1065
# Epoch 2/40
# 105/105 [==============================] - 14s 128ms/step - loss: 3.3013 - accuracy: 0.1776 - val_loss: 2.6431 - val_accuracy: 0.3457
# Epoch 3/40
# 105/105 [==============================] - 14s 129ms/step - loss: 2.5826 - accuracy: 0.3272 - val_loss: 2.0728 - val_accuracy: 0.4653
# Epoch 4/40
# 105/105 [==============================] - 14s 127ms/step - loss: 2.0709 - accuracy: 0.4357 - val_loss: 1.7227 - val_accuracy: 0.5120
# Epoch 5/40
# 105/105 [==============================] - 14s 128ms/step - loss: 1.7883 - accuracy: 0.4892 - val_loss: 1.2431 - val_accuracy: 0.6615
# Epoch 6/40
# 105/105 [==============================] - 14s 128ms/step - loss: 1.5047 - accuracy: 0.5595 - val_loss: 1.1488 - val_accuracy: 0.6866
# Epoch 7/40
# 105/105 [==============================] - 14s 130ms/step - loss: 1.3858 - accuracy: 0.5783 - val_loss: 0.9621 - val_accuracy: 0.7033
# Epoch 8/40
# 105/105 [==============================] - 14s 127ms/step - loss: 1.1957 - accuracy: 0.6370 - val_loss: 0.7850 - val_accuracy: 0.7560
# Epoch 9/40
# 105/105 [==============================] - 14s 126ms/step - loss: 1.0586 - accuracy: 0.6794 - val_loss: 0.6585 - val_accuracy: 0.7978
# Epoch 10/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.9850 - accuracy: 0.6944 - val_loss: 0.6963 - val_accuracy: 0.7632
# Epoch 11/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.9343 - accuracy: 0.7150 - val_loss: 0.6317 - val_accuracy: 0.8014
# Epoch 12/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.8517 - accuracy: 0.7312 - val_loss: 0.4844 - val_accuracy: 0.8397
# Epoch 13/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.7893 - accuracy: 0.7476 - val_loss: 0.4883 - val_accuracy: 0.8397
# Epoch 14/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.7469 - accuracy: 0.7599 - val_loss: 0.4440 - val_accuracy: 0.8612
# Epoch 15/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.6699 - accuracy: 0.7835 - val_loss: 0.4157 - val_accuracy: 0.8696
# Epoch 16/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.6781 - accuracy: 0.7823 - val_loss: 0.3740 - val_accuracy: 0.8935
# Epoch 17/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.6459 - accuracy: 0.7883 - val_loss: 0.4149 - val_accuracy: 0.8756
# Epoch 18/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.6497 - accuracy: 0.7883 - val_loss: 0.4154 - val_accuracy: 0.8804
# Epoch 19/40
# 105/105 [==============================] - 15s 137ms/step - loss: 0.5995 - accuracy: 0.8116 - val_loss: 0.3212 - val_accuracy: 0.9055
# Epoch 20/40
# 105/105 [==============================] - 15s 137ms/step - loss: 0.5586 - accuracy: 0.8233 - val_loss: 0.3406 - val_accuracy: 0.9031
# Epoch 21/40
# 105/105 [==============================] - 15s 131ms/step - loss: 0.5270 - accuracy: 0.8245 - val_loss: 0.3512 - val_accuracy: 0.8923
# Epoch 22/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.5288 - accuracy: 0.8334 - val_loss: 0.2945 - val_accuracy: 0.9139
# Epoch 23/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4746 - accuracy: 0.8409 - val_loss: 0.2701 - val_accuracy: 0.9234
# Epoch 24/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.4699 - accuracy: 0.8427 - val_loss: 0.2418 - val_accuracy: 0.9354
# Epoch 25/40
# 105/105 [==============================] - 15s 134ms/step - loss: 0.4243 - accuracy: 0.8648 - val_loss: 0.2485 - val_accuracy: 0.9306
# Epoch 26/40
# 105/105 [==============================] - 15s 132ms/step - loss: 0.4435 - accuracy: 0.8580 - val_loss: 0.2590 - val_accuracy: 0.9330
# Epoch 27/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4025 - accuracy: 0.8735 - val_loss: 0.2160 - val_accuracy: 0.9462
# Epoch 28/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4034 - accuracy: 0.8726 - val_loss: 0.2438 - val_accuracy: 0.9462
# Epoch 29/40
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3491 - accuracy: 0.8855 - val_loss: 0.2005 - val_accuracy: 0.9510
# Epoch 30/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4051 - accuracy: 0.8690 - val_loss: 0.1965 - val_accuracy: 0.9474
# Epoch 31/40
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3396 - accuracy: 0.8947 - val_loss: 0.1724 - val_accuracy: 0.9593
# Epoch 32/40
# 105/105 [==============================] - 14s 127ms/step - loss: 0.3317 - accuracy: 0.8980 - val_loss: 0.1607 - val_accuracy: 0.9557
# Epoch 33/40
# 105/105 [==============================] - 14s 125ms/step - loss: 0.3225 - accuracy: 0.8935 - val_loss: 0.1956 - val_accuracy: 0.9593
# Epoch 34/40
# 105/105 [==============================] - 15s 135ms/step - loss: 0.2989 - accuracy: 0.9067 - val_loss: 0.1798 - val_accuracy: 0.9641
# Epoch 35/40
# 105/105 [==============================] - 14s 126ms/step - loss: 0.2961 - accuracy: 0.9073 - val_loss: 0.1969 - val_accuracy: 0.9581
# Epoch 36/40
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2920 - accuracy: 0.9076 - val_loss: 0.2021 - val_accuracy: 0.9593
# Epoch 37/40
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2879 - accuracy: 0.9127 - val_loss: 0.1861 - val_accuracy: 0.9557

# %%
# Plot the accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Print accuracy and confusion matrix
print("Accuracy:")
accuracy = model.evaluate(val_ds)[1]
print(f"{accuracy * 100:.2f}%")
# Out:
# Accuracy:
# 27/27 [==============================] - 2s 53ms/step - loss: 0.1861 - accuracy: 0.9557
# 95.57%

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn','Go straight or right','Go straight','Danger Ahead','Zebra Crossing','Under Construction','Heavy Vehicle Accidents','No entry','Dont Go straight or left','Dont Go straight or Right']

# %%
print(labels)
# Out:
# tf.Tensor(
# [21  3 17  5 23 12  0 15  9 23 21 54 17  9 17 51 50 56 45 51 23 51 40  4
#  50  8 50 21 45  7 25 34], shape=(32,), dtype=int32)

# %%
# Predict classes for the validation set
val_images = []
val_labels = []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)

# Convert class_names to a list of strings
class_names = [str(class_name) for class_name in class_names]

# Create a classification report
classification_rep = classification_report(val_labels, val_predictions, labels=class_numbers, target_names=class_names)
print("Classification Report:")
print(classification_rep)
# Out:
# 27/27 [==============================] - 1s 32ms/step
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Speed limit (5km/h)       0.83      1.00      0.91        24
#         Speed limit (15km/h)       1.00      0.75      0.86         4
#             Dont Go straight       0.00      0.00      0.00         3
#                 Dont Go Left       0.00      0.00      0.00         1
#        Dont Go Left or Right       0.89      0.89      0.89         9
#                Dont Go Right       1.00      1.00      1.00         1
#      Dont overtake from Left       1.00      1.00      1.00         2
#                     No Uturn       1.00      1.00      1.00         1
#                       No Car       1.00      1.00      1.00         3
#                      No horn       1.00      0.85      0.92        26
#         Speed limit (40km/h)       0.00      0.00      0.00         0
#         Speed limit (50km/h)       1.00      0.95      0.98        21
#         Speed limit (30km/h)       0.79      1.00      0.88        11
#         Go straight or right       1.00      1.00      1.00         7
#                  Go straight       1.00      0.99      0.99        89
#                      Go Left       1.00      1.00      1.00         9
#             Go Left or right       0.95      1.00      0.97        52
#                     Go Right       1.00      1.00      1.00        21
#                    keep Left       1.00      1.00      1.00         8
#                   keep Right       1.00      1.00      1.00         2
#         Roundabout mandatory       1.00      1.00      1.00         1
#           watch out for cars       0.50      1.00      0.67         2
#                         Horn       1.00      1.00      1.00        33
#         Speed limit (40km/h)       1.00      1.00      1.00        31
#            Bicycles crossing       0.83      1.00      0.91        10
#                        Uturn       0.94      0.94      0.94        16
#                 Road Divider       1.00      0.40      0.57         5
#              Traffic signals       0.62      0.80      0.70        10
#                 Danger Ahead       1.00      0.94      0.97        18
#               Zebra Crossing       1.00      1.00      1.00         7
#            Bicycles crossing       1.00      1.00      1.00         2
#            Children crossing       1.00      0.50      0.67        10
#  Dangerous curve to the left       0.86      1.00      0.92        18
# Dangerous curve to the right       0.00      0.00      0.00         2
#         Speed limit (50km/h)       1.00      1.00      1.00        22
#                     Unknown1       1.00      0.57      0.73         7
#                     Unknown2       1.00      0.67      0.80         3
#                     Unknown3       0.50      1.00      0.67         1
#         Go right or straight       1.00      1.00      1.00         2
#          Go left or straight       1.00      0.62      0.77         8
#                     Unknown4       1.00      1.00      1.00        43
#                 ZigZag Curve       1.00      1.00      1.00        11
#               Train Crossing       1.00      1.00      1.00         2
#           Under Construction       1.00      1.00      1.00        10
#                     Unknown5       0.00      0.00      0.00         0
#         Speed limit (60km/h)       0.78      1.00      0.88         7
#                       Fences       0.97      1.00      0.99        69
#      Heavy Vehicle Accidents       1.00      1.00      1.00        34
#                     Unknown6       0.85      1.00      0.92        22
#                     Give Way       1.00      1.00      1.00         1
#                  No stopping       1.00      1.00      1.00        16
#                     No entry       0.93      1.00      0.96        26
#                     Unknown7       1.00      0.20      0.33         5
#                     Unknown8       0.00      0.00      0.00         0
#         Speed limit (70km/h)       1.00      1.00      1.00        25
#         speed limit (80km/h)       1.00      1.00      1.00         4
#     Dont Go straight or left       0.96      1.00      0.98        27
#    Dont Go straight or Right       1.00      1.00      1.00        32
#
#                    micro avg       0.96      0.96      0.96       836
#                    macro avg       0.85      0.83      0.82       836
#                 weighted avg       0.96      0.96      0.95       836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Speed limit (30km/h)', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (60km/h)', 'Speed limit (70km/h)', 'Speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)','Go straight or right','Go straight','Go Left','Go Left or right','Go Right','Keep Left','Keep Right','Roundabout mandatory','watch out for cars','Horn','Bicycles crossing','Uturn','Road Divider','Traffic signals','Danger Ahead','Zebra Crossing','Bicycles crossing','Children crossing','Dangerous curve to the left','Dangerous curve to the right','Unknown1','Unknown2','Unknown3','Go right or straight','Go left or straight','Unknown4','ZigZag Curve','Train Crossing','Under Construction','Unknown5','Fences','Heavy Vehicle Accidents','Unknown6','Give Way','No stopping','No entry','Unknown7','Unknown8']

# Generate random values for val_predictions and val_labels
num_samples = 3344
num_classes = len(class_labels)  # Use the actual number of unique class labels

# Generate random values for val_predictions and val_labels
val_predictions = np.random.randint(0, num_classes, size=num_samples)
val_labels = np.random.randint(0, num_classes, size=num_samples)

# Create the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_predictions, labels=range(num_classes))

# Plot the larger confusion matrix
plt.figure(figsize=(18, 16))  # Adjust the figure size for larger plot
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Greens', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix: ')
plt.show()
