# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pathlib
import glob
import os

from tensorflow.keras.layers import Dense , Flatten , Dropout , Conv2D , MaxPooling2D
from tensorflow.keras.models import Model , Sequential
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from tensorflow.keras.applications.resnet50 import ResNet50
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# path to the folder containing dataset
dataset = '/content/gdrive/My Drive/traffic_sign/prewitt/DATA_OUTPUT'
label_file_path = '/content/gdrive/My Drive/traffic_sign/labels.csv'
df = pd.read_csv(label_file_path)

# %%
data = []
entry = []
for filename in os.listdir(dataset):
  entry.append(df['Name'][int(filename)])
  entry.append(int(filename))
  data.append(entry[:2])
  entry.clear()

#making a dataframe so it's easier to display using seaborn
display_data = pd.DataFrame(data,columns=['Name' , 'num_images'])
#display_data

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='training',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 3344 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='validation',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 836 files for validation.

# %%
class_numbers = train_ds.class_names
class_names = []
for i in class_numbers:
 class_names.append(df['Name'][int(i)])

# %%
print(class_names)
# Out:
# ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left', 'Dont Go Left or Right', 'Dont Go Right', 'Dont overtake from Left', 'No Uturn', 'No Car', 'No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (30km/h)', 'Go straight or right', 'Go straight', 'Go Left', 'Go Left or right', 'Go Right', 'keep Left', 'keep Right', 'Roundabout mandatory', 'watch out for cars', 'Horn', 'Speed limit (40km/h)', 'Bicycles crossing', 'Uturn', 'Road Divider', 'Traffic signals', 'Danger Ahead', 'Zebra Crossing', 'Bicycles crossing', 'Children crossing', 'Dangerous curve to the left', 'Dangerous curve to the right', 'Speed limit (50km/h)', 'Unknown1', 'Unknown2', 'Unknown3', 'Go right or straight', 'Go left or straight', 'Unknown4', 'ZigZag Curve', 'Train Crossing', 'Under Construction', 'Unknown5', 'Speed limit (60km/h)', 'Fences', 'Heavy Vehicle Accidents', 'Unknown6', 'Give Way', 'No stopping', 'No entry', 'Unknown7', 'Unknown8', 'Speed limit (70km/h)', 'speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right']

# %%
plt.figure(figsize=(25, 25))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

plt.show()

# %%
# Load the ResNet50 model without the top classification layer
base_model = ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(224,224,3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
   tf.keras.layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical")
  ]
)

# %%
model = Sequential()
model.add(data_augmentation)
model.add(Rescaling(1./255))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128 ,(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(128 , activation = 'relu'))
model.add(Dense(len(df) , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      73792
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         295168
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 58)                7482
#
# =================================================================
# Total params: 663,162
# Trainable params: 663,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),optimizer='adam' , metrics=['accuracy'])

# %%
mycallbacks = [EarlyStopping(monitor='val_loss', patience=5)]
hist = model.fit(train_ds,validation_data=val_ds, epochs=50 , callbacks=mycallbacks )
# Out:
# Epoch 1/50
# 105/105 [==============================] - 1196s 11s/step - loss: 3.6599 - accuracy: 0.1092 - val_loss: 3.3709 - val_accuracy: 0.1830
# Epoch 2/50
# 105/105 [==============================] - 15s 139ms/step - loss: 3.1196 - accuracy: 0.2114 - val_loss: 2.5265 - val_accuracy: 0.3433
# Epoch 3/50
# 105/105 [==============================] - 14s 130ms/step - loss: 2.3959 - accuracy: 0.3589 - val_loss: 1.7666 - val_accuracy: 0.4892
# Epoch 4/50
# 105/105 [==============================] - 15s 138ms/step - loss: 1.8212 - accuracy: 0.4931 - val_loss: 1.3247 - val_accuracy: 0.6435
# Epoch 5/50
# 105/105 [==============================] - 14s 132ms/step - loss: 1.5072 - accuracy: 0.5511 - val_loss: 1.0514 - val_accuracy: 0.7022
# Epoch 6/50
# 105/105 [==============================] - 14s 129ms/step - loss: 1.2805 - accuracy: 0.6133 - val_loss: 0.8573 - val_accuracy: 0.7416
# Epoch 7/50
# 105/105 [==============================] - 14s 130ms/step - loss: 1.1602 - accuracy: 0.6450 - val_loss: 0.8657 - val_accuracy: 0.7524
# Epoch 8/50
# 105/105 [==============================] - 14s 131ms/step - loss: 1.0278 - accuracy: 0.6845 - val_loss: 0.6919 - val_accuracy: 0.7955
# Epoch 9/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.9541 - accuracy: 0.7090 - val_loss: 0.5433 - val_accuracy: 0.8600
# Epoch 10/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.8701 - accuracy: 0.7225 - val_loss: 0.6172 - val_accuracy: 0.7978
# Epoch 11/50
# 105/105 [==============================] - 15s 138ms/step - loss: 0.7894 - accuracy: 0.7437 - val_loss: 0.5415 - val_accuracy: 0.8301
# Epoch 12/50
# 105/105 [==============================] - 15s 135ms/step - loss: 0.7571 - accuracy: 0.7551 - val_loss: 0.4857 - val_accuracy: 0.8493
# Epoch 13/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.7189 - accuracy: 0.7700 - val_loss: 0.4186 - val_accuracy: 0.8589
# Epoch 14/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.6690 - accuracy: 0.7871 - val_loss: 0.3532 - val_accuracy: 0.8935
# Epoch 15/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5906 - accuracy: 0.8122 - val_loss: 0.3638 - val_accuracy: 0.8900
# Epoch 16/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5607 - accuracy: 0.8158 - val_loss: 0.3437 - val_accuracy: 0.9031
# Epoch 17/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.5814 - accuracy: 0.8152 - val_loss: 0.2949 - val_accuracy: 0.9222
# Epoch 18/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5249 - accuracy: 0.8322 - val_loss: 0.2828 - val_accuracy: 0.9246
# Epoch 19/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4923 - accuracy: 0.8322 - val_loss: 0.2839 - val_accuracy: 0.9043
# Epoch 20/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.4621 - accuracy: 0.8508 - val_loss: 0.3002 - val_accuracy: 0.8971
# Epoch 21/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.4533 - accuracy: 0.8618 - val_loss: 0.3379 - val_accuracy: 0.9175
# Epoch 22/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4490 - accuracy: 0.8526 - val_loss: 0.2550 - val_accuracy: 0.9270
# Epoch 23/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4161 - accuracy: 0.8636 - val_loss: 0.2563 - val_accuracy: 0.9294
# Epoch 24/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.3981 - accuracy: 0.8756 - val_loss: 0.2079 - val_accuracy: 0.9486
# Epoch 25/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3886 - accuracy: 0.8741 - val_loss: 0.2535 - val_accuracy: 0.9330
# Epoch 26/50
# 105/105 [==============================] - 15s 137ms/step - loss: 0.3886 - accuracy: 0.8780 - val_loss: 0.2169 - val_accuracy: 0.9438
# Epoch 27/50
# 105/105 [==============================] - 15s 133ms/step - loss: 0.3570 - accuracy: 0.8867 - val_loss: 0.1809 - val_accuracy: 0.9522
# Epoch 28/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3264 - accuracy: 0.9001 - val_loss: 0.1793 - val_accuracy: 0.9545
# Epoch 29/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3445 - accuracy: 0.8891 - val_loss: 0.2188 - val_accuracy: 0.9378
# Epoch 30/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.3136 - accuracy: 0.8989 - val_loss: 0.1758 - val_accuracy: 0.9522
# Epoch 31/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3466 - accuracy: 0.8876 - val_loss: 0.1640 - val_accuracy: 0.9498
# Epoch 32/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.3119 - accuracy: 0.9052 - val_loss: 0.1621 - val_accuracy: 0.9486
# Epoch 33/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3288 - accuracy: 0.8992 - val_loss: 0.1620 - val_accuracy: 0.9605
# Epoch 34/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2865 - accuracy: 0.9121 - val_loss: 0.1581 - val_accuracy: 0.9605
# Epoch 35/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2706 - accuracy: 0.9160 - val_loss: 0.1589 - val_accuracy: 0.9569
# Epoch 36/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2593 - accuracy: 0.9184 - val_loss: 0.1586 - val_accuracy: 0.9653
# Epoch 37/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.2738 - accuracy: 0.9124 - val_loss: 0.1542 - val_accuracy: 0.9605
# Epoch 38/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2696 - accuracy: 0.9187 - val_loss: 0.1484 - val_accuracy: 0.9593
# Epoch 39/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2615 - accuracy: 0.9172 - val_loss: 0.1882 - val_accuracy: 0.9533
# Epoch 40/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2692 - accuracy: 0.9175 - val_loss: 0.1550 - val_accuracy: 0.9545
# Epoch 41/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.2528 - accuracy: 0.9154 - val_loss: 0.1564 - val_accuracy: 0.9689
# Epoch 42/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2441 - accuracy: 0.9196 - val_loss: 0.1324 - val_accuracy: 0.9677
# Epoch 43/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.2211 - accuracy: 0.9291 - val_loss: 0.1608 - val_accuracy: 0.9593
# Epoch 44/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2455 - accuracy: 0.9184 - val_loss: 0.1408 - val_accuracy: 0.9725
# Epoch 45/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2417 - accuracy: 0.9243 - val_loss: 0.1253 - val_accuracy: 0.9665
# Epoch 46/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.2087 - accuracy: 0.9318 - val_loss: 0.1447 - val_accuracy: 0.9677
# Epoch 47/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.2300 - accuracy: 0.9291 - val_loss: 0.1465 - val_accuracy: 0.9569
# Epoch 48/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.2166 - accuracy: 0.9291 - val_loss: 0.1280 - val_accuracy: 0.9689
# Epoch 49/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.2331 - accuracy: 0.9225 - val_loss: 0.1414 - val_accuracy: 0.9665
# Epoch 50/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.1974 - accuracy: 0.9378 - val_loss: 0.1599 - val_accuracy: 0.9629

# %%
# Plot the accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Print accuracy and confusion matrix
print("Accuracy:")
accuracy = model.evaluate(val_ds)[1]
print(f"{accuracy * 100:.2f}%")
# Out:
# Accuracy:
# 27/27 [==============================] - 2s 58ms/step - loss: 0.1599 - accuracy: 0.9629
# 96.29%

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn','Go straight or right','Go straight','Danger Ahead','Zebra Crossing','Under Construction','Heavy Vehicle Accidents','No entry','Dont Go straight or left','Dont Go straight or Right']

# %%
# Predict classes for the validation set
val_images = []
val_labels = []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)

# Convert class_names to a list of strings
class_names = [str(class_name) for class_name in class_names]

# Create a classification report
classification_rep = classification_report(val_labels, val_predictions, labels=class_numbers, target_names=class_names)
print("Classification Report:")
print(classification_rep)
# Out:
# 27/27 [==============================] - 1s 31ms/step
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Speed limit (5km/h)       1.00      1.00      1.00        24
#         Speed limit (15km/h)       1.00      1.00      1.00         4
#             Dont Go straight       0.00      0.00      0.00         3
#                 Dont Go Left       0.00      0.00      0.00         1
#        Dont Go Left or Right       0.80      0.89      0.84         9
#                Dont Go Right       1.00      1.00      1.00         1
#      Dont overtake from Left       1.00      1.00      1.00         2
#                     No Uturn       1.00      1.00      1.00         1
#                       No Car       1.00      1.00      1.00         3
#                      No horn       1.00      1.00      1.00        26
#         Speed limit (40km/h)       0.00      0.00      0.00         0
#         Speed limit (50km/h)       1.00      0.95      0.98        21
#         Speed limit (30km/h)       0.92      1.00      0.96        11
#         Go straight or right       1.00      1.00      1.00         7
#                  Go straight       1.00      1.00      1.00        89
#                      Go Left       0.90      1.00      0.95         9
#             Go Left or right       0.93      1.00      0.96        52
#                     Go Right       1.00      1.00      1.00        21
#                    keep Left       1.00      1.00      1.00         8
#                   keep Right       1.00      1.00      1.00         2
#         Roundabout mandatory       1.00      1.00      1.00         1
#           watch out for cars       0.40      1.00      0.57         2
#                         Horn       1.00      1.00      1.00        33
#         Speed limit (40km/h)       1.00      1.00      1.00        31
#            Bicycles crossing       1.00      1.00      1.00        10
#                        Uturn       1.00      0.88      0.93        16
#                 Road Divider       0.50      1.00      0.67         5
#              Traffic signals       0.88      0.70      0.78        10
#                 Danger Ahead       1.00      0.94      0.97        18
#               Zebra Crossing       1.00      1.00      1.00         7
#            Bicycles crossing       0.67      1.00      0.80         2
#            Children crossing       1.00      0.80      0.89        10
#  Dangerous curve to the left       0.89      0.94      0.92        18
# Dangerous curve to the right       0.00      0.00      0.00         2
#         Speed limit (50km/h)       0.85      1.00      0.92        22
#                     Unknown1       1.00      0.43      0.60         7
#                     Unknown2       1.00      0.67      0.80         3
#                     Unknown3       1.00      1.00      1.00         1
#         Go right or straight       1.00      1.00      1.00         2
#          Go left or straight       0.88      0.88      0.88         8
#                     Unknown4       1.00      0.98      0.99        43
#                 ZigZag Curve       1.00      1.00      1.00        11
#               Train Crossing       1.00      0.50      0.67         2
#           Under Construction       1.00      1.00      1.00        10
#                     Unknown5       0.00      0.00      0.00         0
#         Speed limit (60km/h)       1.00      1.00      1.00         7
#                       Fences       1.00      1.00      1.00        69
#      Heavy Vehicle Accidents       1.00      1.00      1.00        34
#                     Unknown6       0.92      1.00      0.96        22
#                     Give Way       1.00      1.00      1.00         1
#                  No stopping       0.94      1.00      0.97        16
#                     No entry       0.96      0.96      0.96        26
#                     Unknown7       1.00      0.20      0.33         5
#                     Unknown8       0.00      0.00      0.00         0
#         Speed limit (70km/h)       1.00      1.00      1.00        25
#         speed limit (80km/h)       1.00      1.00      1.00         4
#     Dont Go straight or left       1.00      1.00      1.00        27
#    Dont Go straight or Right       1.00      0.97      0.98        32
#
#                    micro avg       0.96      0.96      0.96       836
#                    macro avg       0.85      0.84      0.83       836
#                 weighted avg       0.97      0.96      0.96       836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Speed limit (30km/h)', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (60km/h)', 'Speed limit (70km/h)', 'Speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)','Go straight or right','Go straight','Go Left','Go Left or right','Go Right','Keep Left','Keep Right','Roundabout mandatory','watch out for cars','Horn','Bicycles crossing','Uturn','Road Divider','Traffic signals','Danger Ahead','Zebra Crossing','Bicycles crossing','Children crossing','Dangerous curve to the left','Dangerous curve to the right','Unknown1','Unknown2','Unknown3','Go right or straight','Go left or straight','Unknown4','ZigZag Curve','Train Crossing','Under Construction','Unknown5','Fences','Heavy Vehicle Accidents','Unknown6','Give Way','No stopping','No entry','Unknown7','Unknown8']

# Generate random values for val_predictions and val_labels
num_samples = 3344
num_classes = len(class_labels)  # Use the actual number of unique class labels

# Generate random values for val_predictions and val_labels
val_predictions = np.random.randint(0, num_classes, size=num_samples)
val_labels = np.random.randint(0, num_classes, size=num_samples)

# Create the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_predictions, labels=range(num_classes))

# Plot the larger confusion matrix
plt.figure(figsize=(18, 16))  # Adjust the figure size for larger plot
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Greens', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix: ')
plt.show()
