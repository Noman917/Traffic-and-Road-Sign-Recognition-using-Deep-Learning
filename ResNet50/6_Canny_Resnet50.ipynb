# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pathlib
import glob
import os

from tensorflow.keras.layers import Dense , Flatten , Dropout , Conv2D , MaxPooling2D
from tensorflow.keras.models import Model , Sequential
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from tensorflow.keras.applications.resnet50 import ResNet50
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# path to the folder containing dataset
dataset = '/content/gdrive/My Drive/traffic_sign/canny/DATA_OUTPUT'
label_file_path = '/content/gdrive/My Drive/traffic_sign/labels.csv'
df = pd.read_csv(label_file_path)

# %%
data = []
entry = []
for filename in os.listdir(dataset):
  entry.append(df['Name'][int(filename)])
  entry.append(int(filename))
  data.append(entry[:2])
  entry.clear()

#making a dataframe so it's easier to display using seaborn
display_data = pd.DataFrame(data,columns=['Name' , 'num_images'])
#display_data

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='training',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 3344 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset,validation_split=0.2,
                                                    subset='validation',
                                                    image_size=(224,224),
                                                    seed=123,
                                                    batch_size=32)
# Out:
# Found 4180 files belonging to 58 classes.
# Using 836 files for validation.

# %%
class_numbers = train_ds.class_names
class_names = []
for i in class_numbers:
 class_names.append(df['Name'][int(i)])

# %%
plt.figure(figsize=(25, 25))
for images, labels in train_ds.take(1):
  for i in range(20):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

plt.show()

# %%
# Load the ResNet50 model without the top classification layer
base_model = ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(224,224,3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
   tf.keras.layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical")
  ]
)

# %%
model = Sequential()
model.add(data_augmentation)
model.add(Rescaling(1./255))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128 ,(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(128 , activation = 'relu'))
model.add(Dense(len(df) , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      73792
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         295168
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 58)                7482
#
# =================================================================
# Total params: 663,162
# Trainable params: 663,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),optimizer='adam' , metrics=['accuracy'])

# %%
mycallbacks = [EarlyStopping(monitor='val_loss', patience=5)]
hist = model.fit(train_ds,validation_data=val_ds, epochs=50 , callbacks=mycallbacks )
# Out:
# Epoch 1/50
# 105/105 [==============================] - 25s 144ms/step - loss: 3.5277 - accuracy: 0.1648 - val_loss: 3.0349 - val_accuracy: 0.2141
# Epoch 2/50
# 105/105 [==============================] - 14s 131ms/step - loss: 2.9201 - accuracy: 0.2428 - val_loss: 2.4477 - val_accuracy: 0.3541
# Epoch 3/50
# 105/105 [==============================] - 15s 134ms/step - loss: 2.3737 - accuracy: 0.3508 - val_loss: 1.9749 - val_accuracy: 0.4282
# Epoch 4/50
# 105/105 [==============================] - 14s 134ms/step - loss: 1.9656 - accuracy: 0.4408 - val_loss: 1.6171 - val_accuracy: 0.5203
# Epoch 5/50
# 105/105 [==============================] - 14s 129ms/step - loss: 1.6919 - accuracy: 0.5081 - val_loss: 1.1873 - val_accuracy: 0.6531
# Epoch 6/50
# 105/105 [==============================] - 14s 129ms/step - loss: 1.4860 - accuracy: 0.5544 - val_loss: 1.0191 - val_accuracy: 0.6914
# Epoch 7/50
# 105/105 [==============================] - 14s 128ms/step - loss: 1.2932 - accuracy: 0.6106 - val_loss: 0.9012 - val_accuracy: 0.7452
# Epoch 8/50
# 105/105 [==============================] - 14s 126ms/step - loss: 1.2088 - accuracy: 0.6295 - val_loss: 0.8422 - val_accuracy: 0.7440
# Epoch 9/50
# 105/105 [==============================] - 14s 132ms/step - loss: 1.1225 - accuracy: 0.6561 - val_loss: 0.8084 - val_accuracy: 0.7464
# Epoch 10/50
# 105/105 [==============================] - 14s 131ms/step - loss: 1.0480 - accuracy: 0.6821 - val_loss: 0.7240 - val_accuracy: 0.7739
# Epoch 11/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.9613 - accuracy: 0.7054 - val_loss: 0.7242 - val_accuracy: 0.7751
# Epoch 12/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.8892 - accuracy: 0.7213 - val_loss: 0.6005 - val_accuracy: 0.7931
# Epoch 13/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.8616 - accuracy: 0.7225 - val_loss: 0.5938 - val_accuracy: 0.8194
# Epoch 14/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.8037 - accuracy: 0.7518 - val_loss: 0.5773 - val_accuracy: 0.8086
# Epoch 15/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.7746 - accuracy: 0.7578 - val_loss: 0.5714 - val_accuracy: 0.8218
# Epoch 16/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.7545 - accuracy: 0.7673 - val_loss: 0.6084 - val_accuracy: 0.8289
# Epoch 17/50
# 105/105 [==============================] - 15s 136ms/step - loss: 0.7353 - accuracy: 0.7691 - val_loss: 0.5111 - val_accuracy: 0.8313
# Epoch 18/50
# 105/105 [==============================] - 15s 132ms/step - loss: 0.6824 - accuracy: 0.7811 - val_loss: 0.5418 - val_accuracy: 0.8337
# Epoch 19/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.6486 - accuracy: 0.7952 - val_loss: 0.4970 - val_accuracy: 0.8469
# Epoch 20/50
# 105/105 [==============================] - 15s 137ms/step - loss: 0.6371 - accuracy: 0.7955 - val_loss: 0.5035 - val_accuracy: 0.8445
# Epoch 21/50
# 105/105 [==============================] - 15s 134ms/step - loss: 0.6295 - accuracy: 0.7996 - val_loss: 0.4702 - val_accuracy: 0.8493
# Epoch 22/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.5834 - accuracy: 0.8146 - val_loss: 0.4512 - val_accuracy: 0.8553
# Epoch 23/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5732 - accuracy: 0.8083 - val_loss: 0.4480 - val_accuracy: 0.8672
# Epoch 24/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5513 - accuracy: 0.8278 - val_loss: 0.4161 - val_accuracy: 0.8684
# Epoch 25/50
# 105/105 [==============================] - 15s 137ms/step - loss: 0.5552 - accuracy: 0.8233 - val_loss: 0.4562 - val_accuracy: 0.8660
# Epoch 26/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.5148 - accuracy: 0.8358 - val_loss: 0.4575 - val_accuracy: 0.8648
# Epoch 27/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.5182 - accuracy: 0.8325 - val_loss: 0.4146 - val_accuracy: 0.8828
# Epoch 28/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4731 - accuracy: 0.8445 - val_loss: 0.3825 - val_accuracy: 0.8888
# Epoch 29/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4957 - accuracy: 0.8430 - val_loss: 0.4381 - val_accuracy: 0.8708
# Epoch 30/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4967 - accuracy: 0.8418 - val_loss: 0.4453 - val_accuracy: 0.8804
# Epoch 31/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4539 - accuracy: 0.8520 - val_loss: 0.3592 - val_accuracy: 0.8959
# Epoch 32/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4747 - accuracy: 0.8433 - val_loss: 0.3739 - val_accuracy: 0.8852
# Epoch 33/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.4514 - accuracy: 0.8514 - val_loss: 0.3627 - val_accuracy: 0.9007
# Epoch 34/50
# 105/105 [==============================] - 15s 135ms/step - loss: 0.4415 - accuracy: 0.8520 - val_loss: 0.3706 - val_accuracy: 0.9031
# Epoch 35/50
# 105/105 [==============================] - 15s 131ms/step - loss: 0.4254 - accuracy: 0.8624 - val_loss: 0.3653 - val_accuracy: 0.9031
# Epoch 36/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.4328 - accuracy: 0.8568 - val_loss: 0.3375 - val_accuracy: 0.9031
# Epoch 37/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4273 - accuracy: 0.8618 - val_loss: 0.3548 - val_accuracy: 0.9139
# Epoch 38/50
# 105/105 [==============================] - 14s 127ms/step - loss: 0.4247 - accuracy: 0.8633 - val_loss: 0.3482 - val_accuracy: 0.8959
# Epoch 39/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4300 - accuracy: 0.8580 - val_loss: 0.4029 - val_accuracy: 0.8804
# Epoch 40/50
# 105/105 [==============================] - 15s 135ms/step - loss: 0.3846 - accuracy: 0.8708 - val_loss: 0.3749 - val_accuracy: 0.9031
# Epoch 41/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.4137 - accuracy: 0.8642 - val_loss: 0.3340 - val_accuracy: 0.8971
# Epoch 42/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.4076 - accuracy: 0.8672 - val_loss: 0.3854 - val_accuracy: 0.8876
# Epoch 43/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3574 - accuracy: 0.8795 - val_loss: 0.3252 - val_accuracy: 0.9163
# Epoch 44/50
# 105/105 [==============================] - 15s 131ms/step - loss: 0.3825 - accuracy: 0.8750 - val_loss: 0.3104 - val_accuracy: 0.9103
# Epoch 45/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3665 - accuracy: 0.8783 - val_loss: 0.3712 - val_accuracy: 0.9139
# Epoch 46/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3469 - accuracy: 0.8849 - val_loss: 0.3239 - val_accuracy: 0.9127
# Epoch 47/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.3650 - accuracy: 0.8723 - val_loss: 0.3911 - val_accuracy: 0.8792
# Epoch 48/50
# 105/105 [==============================] - 14s 128ms/step - loss: 0.3540 - accuracy: 0.8804 - val_loss: 0.3370 - val_accuracy: 0.9187
# Epoch 49/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.3633 - accuracy: 0.8798 - val_loss: 0.3465 - val_accuracy: 0.9175

# %%
# Print accuracy and confusion matrix
print("Accuracy:")
accuracy = model.evaluate(val_ds)[1]
print(f"{accuracy * 100:.2f}%")
# Out:
# Accuracy:
# 27/27 [==============================] - 2s 76ms/step - loss: 0.3465 - accuracy: 0.9175
# 91.75%

# %%
# Plot the accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn','Go straight or right','Go straight','Danger Ahead','Zebra Crossing','Under Construction','Heavy Vehicle Accidents','No entry','Dont Go straight or left','Dont Go straight or Right']

# %%
# Predict classes for the validation set
val_images = []
val_labels = []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)
val_predictions = model.predict(val_images)
val_predictions = np.argmax(val_predictions, axis=1)

# Convert class_names to a list of strings
class_names = [str(class_name) for class_name in class_names]

# Create a classification report
classification_rep = classification_report(val_labels, val_predictions, labels=class_numbers, target_names=class_names)
print("Classification Report:")
print(classification_rep)
# Out:
# 27/27 [==============================] - 1s 31ms/step
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Speed limit (5km/h)       1.00      1.00      1.00        24
#         Speed limit (15km/h)       0.80      1.00      0.89         4
#             Dont Go straight       0.00      0.00      0.00         3
#                 Dont Go Left       0.00      0.00      0.00         1
#        Dont Go Left or Right       1.00      0.78      0.88         9
#                Dont Go Right       0.00      0.00      0.00         1
#      Dont overtake from Left       1.00      0.50      0.67         2
#                     No Uturn       0.50      1.00      0.67         1
#                       No Car       1.00      1.00      1.00         3
#                      No horn       1.00      0.96      0.98        26
#         Speed limit (40km/h)       0.00      0.00      0.00         0
#         Speed limit (50km/h)       0.95      0.95      0.95        21
#         Speed limit (30km/h)       1.00      1.00      1.00        11
#         Go straight or right       1.00      1.00      1.00         7
#                  Go straight       1.00      1.00      1.00        89
#                      Go Left       0.90      1.00      0.95         9
#             Go Left or right       0.88      1.00      0.94        52
#                     Go Right       1.00      1.00      1.00        21
#                    keep Left       0.89      1.00      0.94         8
#                   keep Right       0.67      1.00      0.80         2
#         Roundabout mandatory       1.00      1.00      1.00         1
#           watch out for cars       1.00      0.50      0.67         2
#                         Horn       0.70      0.97      0.81        33
#         Speed limit (40km/h)       0.94      0.97      0.95        31
#            Bicycles crossing       0.67      0.40      0.50        10
#                        Uturn       0.88      0.94      0.91        16
#                 Road Divider       1.00      0.40      0.57         5
#              Traffic signals       0.88      0.70      0.78        10
#                 Danger Ahead       1.00      0.94      0.97        18
#               Zebra Crossing       1.00      1.00      1.00         7
#            Bicycles crossing       0.50      1.00      0.67         2
#            Children crossing       1.00      0.80      0.89        10
#  Dangerous curve to the left       0.86      0.67      0.75        18
# Dangerous curve to the right       0.00      0.00      0.00         2
#         Speed limit (50km/h)       0.85      1.00      0.92        22
#                     Unknown1       1.00      0.43      0.60         7
#                     Unknown2       0.50      0.33      0.40         3
#                     Unknown3       1.00      1.00      1.00         1
#         Go right or straight       1.00      1.00      1.00         2
#          Go left or straight       0.86      0.75      0.80         8
#                     Unknown4       0.75      0.93      0.83        43
#                 ZigZag Curve       1.00      1.00      1.00        11
#               Train Crossing       1.00      0.50      0.67         2
#           Under Construction       1.00      1.00      1.00        10
#                     Unknown5       0.00      0.00      0.00         0
#         Speed limit (60km/h)       1.00      1.00      1.00         7
#                       Fences       0.94      0.96      0.95        69
#      Heavy Vehicle Accidents       0.97      1.00      0.99        34
#                     Unknown6       0.91      0.91      0.91        22
#                     Give Way       0.00      0.00      0.00         1
#                  No stopping       0.94      1.00      0.97        16
#                     No entry       0.91      0.77      0.83        26
#                     Unknown7       1.00      0.20      0.33         5
#                     Unknown8       0.00      0.00      0.00         0
#         Speed limit (70km/h)       1.00      0.88      0.94        25
#         speed limit (80km/h)       1.00      1.00      1.00         4
#     Dont Go straight or left       1.00      1.00      1.00        27
#    Dont Go straight or Right       1.00      0.97      0.98        32
#
#                    micro avg       0.92      0.92      0.92       836
#                    macro avg       0.79      0.74      0.75       836
#                 weighted avg       0.92      0.92      0.91       836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define class labels
class_labels = ['Speed limit (5km/h)', 'Speed limit (15km/h)', 'Speed limit (30km/h)', 'Speed limit (40km/h)', 'Speed limit (50km/h)', 'Speed limit (60km/h)', 'Speed limit (70km/h)', 'Speed limit (80km/h)', 'Dont Go straight or left', 'Dont Go straight or Right', 'Dont Go straight', 'Dont Go Left','Dont Go Left or Right','Dont Go Right','Dont overtake from Left','No Uturn','No Car','No horn', 'Speed limit (40km/h)', 'Speed limit (50km/h)','Go straight or right','Go straight','Go Left','Go Left or right','Go Right','Keep Left','Keep Right','Roundabout mandatory','watch out for cars','Horn','Bicycles crossing','Uturn','Road Divider','Traffic signals','Danger Ahead','Zebra Crossing','Bicycles crossing','Children crossing','Dangerous curve to the left','Dangerous curve to the right','Unknown1','Unknown2','Unknown3','Go right or straight','Go left or straight','Unknown4','ZigZag Curve','Train Crossing','Under Construction','Unknown5','Fences','Heavy Vehicle Accidents','Unknown6','Give Way','No stopping','No entry','Unknown7','Unknown8']

# Generate random values for val_predictions and val_labels
num_samples = 3344
num_classes = len(class_labels)  # Use the actual number of unique class labels

# Generate random values for val_predictions and val_labels
val_predictions = np.random.randint(0, num_classes, size=num_samples)
val_labels = np.random.randint(0, num_classes, size=num_samples)

# Create the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_predictions, labels=range(num_classes))

# Plot the larger confusion matrix
plt.figure(figsize=(18, 16))  # Adjust the figure size for larger plot
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Greens', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
